# %% [markdown]
# # Day 2: Embeddings & Vector Databases
#
# ## Learning Objectives
# - Understand what embeddings are and how they work
# - Generate text embeddings using OpenAI and Google Gemini
# - Perform vector similarity search
# - Work with vector databases
# - Build a semantic search application

# %%
# Import necessary libraries
import os
from dotenv import load_dotenv
import openai
import google.generativeai as genai
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

load_dotenv()
print("✅ Setup complete!")

# %% [markdown]
# ## 1. Understanding Embeddings
#
# Embeddings are dense vector representations of text that capture semantic meaning. Similar texts have similar embeddings in vector space.

# %%
# TODO: Generate embeddings for sample texts
# Experiment with different embedding models

# %% [markdown]
# ## 2. Vector Similarity and Search
#
# Learn how to compare embeddings and find similar content.

# %%
# TODO: Implement cosine similarity search
# Compare different texts based on their embeddings

# %% [markdown]
# ## 3. Building a Semantic Search System
#
# Create a simple semantic search engine using embeddings.

# %%
# TODO: Build a semantic search function
# 1. Create a document collection
# 2. Generate embeddings for all documents
# 3. Implement search functionality

# %% [markdown]
# ## 4. Exercises
#
# 1. Create embeddings for a dataset of your choice
# 2. Implement k-nearest neighbor search
# 3. Build a question-answering system using semantic search
# 4. Compare embedding quality across different models
# 5. Experiment with different distance metrics (cosine, euclidean, dot product)
#
# ## Notes and Observations
#
# Document your findings:
# -
# -
