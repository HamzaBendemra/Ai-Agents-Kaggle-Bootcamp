# %% [markdown]
# # Day 3: AI Agents
#
# ## Learning Objectives
# - Understand what AI agents are and their architectures
# - Learn different agent design patterns and frameworks
# - Implement function calling and tool integration
# - Build autonomous agents that can plan and execute tasks
# - Explore ReAct (Reasoning + Acting) pattern

# %%
# Import necessary libraries
import os
from dotenv import load_dotenv
import openai
import google.generativeai as genai
import json

load_dotenv()
print("✅ Setup complete!")

# %% [markdown]
# ## 1. What are AI Agents?
#
# AI Agents are autonomous systems that can:
# - Perceive their environment
# - Make decisions based on goals
# - Take actions to achieve objectives
# - Learn from feedback
#
# Key components:
# - **LLM Brain**: Decision-making core
# - **Tools**: Actions the agent can perform
# - **Memory**: Context and history
# - **Planning**: Breaking down complex tasks

# %%
# TODO: Build a simple agent that can answer questions
# Start with basic agent structure

# %% [markdown]
# ## 2. Function Calling & Tool Integration
#
# Learn how to give your agent access to external tools and APIs.

# %%
# TODO: Implement function calling
# Create tools for: calculator, web search, weather API, etc.
# Define tool schemas and implement tool execution

# %% [markdown]
# ## 3. ReAct Pattern (Reasoning + Acting)
#
# The ReAct pattern helps agents:
# 1. **Think**: Reason about the task
# 2. **Act**: Take an action using a tool
# 3. **Observe**: Process the result
# 4. **Repeat**: Continue until goal is achieved

# %%
# TODO: Build a ReAct agent
# Implement the reasoning and acting loop

# %% [markdown]
# ## 4. Agent Frameworks
#
# Popular frameworks to explore:
# - LangChain
# - AutoGen
# - CrewAI
# - LlamaIndex Agents
#
# ## Exercises
#
# 1. Build an agent with at least 3 different tools
# 2. Implement a ReAct agent that can solve multi-step problems
# 3. Create an agent that can search the web and summarize findings
# 4. Add memory to your agent for context retention
# 5. Test your agent with complex, real-world tasks
#
# ## Notes and Observations
#
# Document your agent's behavior:
# -
# -
