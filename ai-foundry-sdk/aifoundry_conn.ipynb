# %%
import os
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from openai import AzureOpenAI
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ### List Azure AI Foundry Project Connections

# %%
try:

    # Get project client
    project_endpoint = os.getenv("AI_FOUNDRY_PROJECT_ENDPOINT")
    project_client = AIProjectClient(
        credential=DefaultAzureCredential(),
        endpoint=project_endpoint,
    )

    ## List all connections in the project
    connections = project_client.connections
    print("List all connections:")
    for connection in connections.list():
        print(f"{connection.name} ({connection.type})")

except Exception as ex:
    print(ex)
# Out:
# List all connections:
# BingSearchAiFoundry (ConnectionType.API_KEY)

# %% [markdown]
# ### Azure AI Foundry Chat Completion Endpoint

# %%
os.getenv("AI_FOUNDRY_PROJECT_ENDPOINT")
# Out:
# 'https://aiengcert-resource.services.ai.azure.com/api/projects/aiengcert'

# %%
try:

    # connect to the project
    project_endpoint = os.getenv("AI_FOUNDRY_PROJECT_ENDPOINT")
    project_client = AIProjectClient(
        credential=DefaultAzureCredential(),
        endpoint=project_endpoint,
    )

    # Get a chat client
    chat_client = project_client.get_openai_client(api_version="2024-12-01-preview")

    # Get a chat completion based on a user-provided prompt
    user_prompt = input("Enter your prompt: ")

    response = chat_client.chat.completions.create(
        model="gpt-5-mini",
        messages=[
            {"role": "system", "content": "You are a helpful AI assistant."},
            {"role": "user", "content": user_prompt},
        ],
    )
    print(response.choices[0].message.content)

except Exception as ex:
    print(ex)
# Out:
# Here’s a concise, practical overview of Microsoft Azure AI Services — what they are, the main offerings, typical uses, and how to get started.
#
# What Azure AI Services are
# - A portfolio of managed cloud services and tools that let you build, deploy, and operate AI solutions at scale.
# - Covers prebuilt, customizable cognitive APIs; large and foundation models; model training, MLOps, and inference infrastructure; and developer tooling and governance capabilities.
# - Integrates with Azure identity, networking, security, compliance, and data services.
#
# Key service families and what they do
# - Azure OpenAI Service
#   - Managed access to OpenAI models (GPT family, embeddings, Codex-style models) hosted on Azure.
#   - Supports generation, chat, code, embeddings, and content moderation.
#   - Enterprise features: Azure AD auth, private endpoints, logging, regional hosting, compliance.
#
# - Azure Cognitive Services (prebuilt APIs)
#   - Vision: Computer Vision, Custom Vision, Face, Form Recognizer (OCR and structured extraction).
#   - Speech: Speech-to-text, text-to-speech, speech translation, speech customization.
#   - Language: Text Analytics (sentiment, key phrases, PII), Translator, Language Understanding (LUIS features), Conversation and Orchestrator.
#   - Decision: Personalizer, Anomaly Detector, Metrics Advisor.
#   - These are REST APIs and SDKs that let you add capabilities quickly without model training.
#
# - Azure AI Studio (and Language Studio)
#   - A unified UI to experiment with, fine-tune, deploy, and manage models (including OpenAI models and Azure-hosted models).
#   - Provides playgrounds for prompts, fine-tuning, and evaluation.
#
# - Azure Machine Learning (Azure ML)
#   - End-to-end platform for training, tuning, registering, deploying, and monitoring custom ML models.
#   - MLOps support, pipelines, automated ML, model explainability, experiment tracking, and compute management (CPU/GPU clusters, inference endpoints).
#   - Integration with Kubernetes, Azure Container Instances, and Azure Arc for hybrid.
#
# - Azure Cognitive Search
#   - Search-as-a-service with built-in AI enrichment, semantic search, and vector search for retrieval-augmented generation (RAG) scenarios.
#   - Common building block together with embeddings from Azure OpenAI to build knowledge-aware chat experiences.
#
# - Containers & Edge
#   - Some Azure AI models can be deployed in containers for inference on AKS, on-premise, or edge devices (with Azure IoT/Edge and Azure Stack/Arc).
#
# Developer tooling & SDKs
# - SDKs: Python, .NET, JavaScript/TypeScript, Java and REST APIs.
# - Tools: Azure Portal, Azure CLI, Visual Studio Code extensions, Azure DevOps/GitHub Actions for CI/CD.
# - Integration with Microsoft products: Power Platform, Dynamics 365, Microsoft 365, and Microsoft Fabric for analytics.
#
# Security, compliance, and governance
# - Enterprise-grade security: Azure AD, role-based access control, network isolation via private endpoints, encryption at-rest/in-transit.
# - Compliance: HIPAA, GDPR, FedRAMP, ISO/IEC standards (availability varies by region and service).
# - Responsible AI support: tools for model explainability, fairness, interpretability, and monitoring; logging and evaluation features to support governance and auditing.
#
# Common use cases
# - Customer service chatbots and virtual assistants
# - Document understanding and automation (invoices, contracts) using Form Recognizer + Cognitive Search
# - Personalized recommendations and anomaly detection
# - Semantic search and knowledge-base Q&A (RAG with embeddings)
# - Speech-enabled apps: transcription, voice assistants, IVR
# - Automated content generation and code assistance
#
# How to choose a service
# - Need a quick capability (vision, speech, translation)? Use Cognitive Services APIs.
# - Need large-model generation or embeddings? Use Azure OpenAI Service or Azure AI Studio.
# - Building custom ML pipelines and full MLOps? Use Azure Machine Learning.
# - Need semantic search over documents / RAG? Use Cognitive Search with embeddings from Azure OpenAI or other models.
# - Need hybrid/on-prem or edge? Use container deployments, Azure Arc, or IoT Edge.
#
# Getting started (short checklist)
# 1. Create an Azure account and set up a subscription.
# 2. Choose and enable the required services (e.g., Azure OpenAI has a separate access request process).
# 3. Use Azure AI Studio or the Portal to experiment with sample data and quickstarts.
# 4. Use SDKs/REST to integrate features into apps; use Cognitive Search + embeddings for knowledge search scenarios.
# 5. Add security: enable Azure AD, private endpoints, and logging/monitoring.
# 6. Apply governance: logging, evaluation, fairness and explainability checks, and cost controls.
#
# Cost considerations
# - Pricing varies by service: per 1,000 transactions (Cognitive Services), per-hour compute and per-inference (Azure ML endpoints), or per-token / per-usage for Azure OpenAI.
# - Expect tradeoffs between higher-latency, lower-cost batch processing and lower-volume, real-time endpoints.
#
# Resources
# - Azure documentation and quickstarts on docs.microsoft.com/azure
# - Azure AI Studio and Azure Portal for hands-on experimentation
# - SDK samples (Python and JavaScript) in Azure GitHub repos
#
# If you tell me your scenario (e.g., document Q&A, conversational assistant, speech transcription, custom model training), I can recommend a specific set of Azure services, an architecture, and sample code or next steps.
